# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Imamul Ahsan**
# <br>
# Masters Student in TU Chemnitz

# %% [markdown]
# *I am interested in Data science because it is a braod field. And it is related to my research purpose*

# %% [markdown]
# ##### Printing a value in python:

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# ### Showing horizontal rule
# <br>
# ***
# <br>
#
# ### Showing bulleted lists
# <br>
# - Bulleted item
# <br>
# - Bulleted item
# <br>
#
# ### Showing numbered lists
# 1. Numbered item
# <br>
# 2. Numbered item
# <br>
#
# ### Showing table
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |
#
# ### Showing hyperlink
# [This is link to Google](www.google.com)
#
# ### Showing images
# ![random.jpg](attachment:random.jpg)
#
#
# ### Showing strikouts
# <s>Strike</s>
